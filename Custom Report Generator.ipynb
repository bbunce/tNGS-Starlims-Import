# %% [markdown]
# # Custom Report Generator
# ### Takes in tNGS outfile and sequencing load file to create 'custom report' file to be able to import into Starlims

# %%
import pandas as pd
import os
import time

# %%
tngs = pd.read_csv('../output/tNGS_export.csv')
# seq = pd.read_csv('../data/seq1.csv',delimiter="\t")
seq = pd.read_csv('../data/seq2.csv',delimiter="\t", header=None)
seq = seq.iloc[4:,:2].copy()
tngs.columns = [c.replace(' ', '_') for c in tngs.columns]
#seq.columns = [c.replace(' ', '_') for c in seq.columns]
seq
# Out:
#         0                         1
# 4    Well               Sample Name
# 5     A01  cnvcontrol01_F_SF2001234
# 6     B01  cnvcontrol01_M_SF2001234
# 7     C01       EX1100630_SF2001234
# 8     D01       EX1702245_SF2001234
# ..    ...                       ...
# 100   F04       EX1816211_SF2001234
# 101   G04       EX1816212_SF2001234
# 102   H04       EX1816215_SF2001234
# 103   A05       EX1816215_SF2001234
# 104   B05    snvcontrol01_SF2001234
#
# [101 rows x 2 columns]

# %%
# Starlims sequencing'NGS' workbatch number
workbatchNo = seq['Container_Name'][0]

# %%
# Get starlims 'amplicon'
star_amplicon = "_NGS_"

# %%
# need to get a dictionary of all sample ID from sequencing load file as that represents what can get 
# imported back into Starlims. Mostly important for the ddPCR mutation details import
samples = list(seq['Plate_ID'].unique())
del samples[:4]
samples = [sample[:9] for sample in samples]

# %%
# new column with sample id and mutsurveyor variant
tngs['id_variant'] = tngs['Folder_number'] + "_" + tngs['MutSurveyor']
tngs_var = list(tngs['id_variant'].unique())
tngs_var = [var for var in tngs_var if str(var) != 'nan']

# %%
# new column with sample id and mutation details variant
tngs['id_mut'] = tngs['Folder_number'] + "_" + tngs['MutDetails']
tngs_mut = list(tngs['id_mut'].unique())

# %%
# new columns with sample id and genomic nomenclature
tngs['id_genomic'] = tngs['Folder_number'] + "_" + tngs['Genomic_nomenclature']
tngs_genomic = list(tngs['id_genomic'].unique())

# %%
# create a dictionary with sample id's and associated variants
sample_vars = {k:[] for k in samples}
for sample in samples:
    for variant in tngs_var:
        if sample == variant[:9]:
            try:
                sample_vars[sample].append(variant[10:])
            except:
                sample_vars[sample] = [variant[10:]]

# %%
# create custom report template
def create_custom_report():
    f = open(f'{os.getcwd()}/../output/custom_report.txt', 'w+')
    header = "Warning!\nSample Name\tReference Name\tLane Quality\tROI Coverage\t#nts below threshold\tQuality ROI\tVariant1\tVariant3\tVariant3\tVariant4\n"
    body = ""
    for sample in sample_vars:
        no_vars = len(sample_vars[sample])
        sample_id = sample + star_amplicon + workbatchNo
        if no_vars == 1:
            body += f"{sample_id}\t\t\t\t\t\t{sample_vars[sample][0]}\n"
        elif no_vars == 2:
            body += f"{sample_id}\t\t\t\t\t\t{sample_vars[sample][0]}\t{sample_vars[sample][1]}\n"        
        elif no_vars == 3:
            body += f"{sample_id}\t\t\t\t\t\t{sample_vars[sample][0]}\t{sample_vars[sample][1]}\t{sample_vars[sample][2]}\n" 
        elif no_vars == 4:
            body += f"{sample_id}\t\t\t\t\t\t{sample_vars[sample][0]}\t{sample_vars[sample][1]}\t{sample_vars[sample][2]}\t{sample_vars[sample][3]}\n"
        else:
            body += f"{sample_id}\t\t\t\t\t\t\t\t\t\t\n"
    f.write(header)
    f.write(body)
    f.close()

create_custom_report()

# %%
# create mutation details 'ddPCR' import file

# cols - well, sampleID, variant

def create_mut_details():
    md_import = seq.iloc[3:,:].copy()

create_mut_details()

# %%
md = seq.iloc[3:,:].copy()
md = md.iloc[:,:2].copy()
md.to_csv("md.csv", header=None, index=False)
md = pd.read_csv("md.csv")
md.columns = [c.replace(' ', '_') for c in md.columns]
md["well_id"] = md["Well"] + "_" + md["Sample_Name"].str[:9]
md
# Out:
#    Well               Sample_Name        well_id
# 0   A01  cnvcontrol01_F_SF2001234  A01_cnvcontro
# 1   B01  cnvcontrol01_M_SF2001234  B01_cnvcontro
# 2   C01       EX1100630_SF2001234  C01_EX1100630
# 3   D01       EX1702245_SF2001234  D01_EX1702245
# 4   E01       EX1714297_SF2001234  E01_EX1714297
# ..  ...                       ...            ...
# 95  F04       EX1816211_SF2001234  F04_EX1816211
# 96  G04       EX1816212_SF2001234  G04_EX1816212
# 97  H04       EX1816215_SF2001234  H04_EX1816215
# 98  A05       EX1816215_SF2001234  A05_EX1816215
# 99  B05    snvcontrol01_SF2001234  B05_snvcontro
#
# [100 rows x 3 columns]

# %% [markdown]
# # Mutation details import
# - Well | SampleID | MutDetail | Genomic
# - Well + SampleID taken from seq.csv
# - MutDetail and Genomic taken from tNGS_export.csv

# %%
list(seq[1])
# Out:
# ['Sample Name',
#  'cnvcontrol01_F_SF2001234',
#  'cnvcontrol01_M_SF2001234',
#  'EX1100630_SF2001234',
#  'EX1702245_SF2001234',
#  'EX1714297_SF2001234',
#  'EX1806104_SF2001234',
#  'EX1806937_SF2001234',
#  'EX1809676_SF2001234',
#  'EX1812034_SF2001234',
#  'EX1812591_SF2001234',
#  'EX1812591_SF2001234',
#  'EX1813292_SF2001234',
#  'EX1813352_SF2001234',
#  'EX1813353_SF2001234',
#  'EX1813386_SF2001234',
#  'EX1813403_SF2001234',
#  'EX1813529_SF2001234',
#  'EX1813576_SF2001234',
#  'EX1813608_SF2001234',
#  'EX1813656_SF2001234',
#  'EX1813905_SF2001234',
#  'EX1813935_SF2001234',
#  'EX1813937_SF2001234',
#  'EX1813996_SF2001234',
#  'EX1814024_SF2001234',
#  'EX1814026_SF2001234',
#  'EX1814264_SF2001234',
#  'EX1814312_SF2001234',
#  'EX1814341_SF2001234',
#  'EX1814400_SF2001234',
#  'EX1814483_SF2001234',
#  'EX1814502_SF2001234',
#  'EX1814537_SF2001234',
#  'EX1814546_SF2001234',
#  'EX1814680_SF2001234',
#  'EX1814711_SF2001234',
#  'EX1814713_SF2001234',
#  'EX1814825_SF2001234',
#  'EX1814881_SF2001234',
#  'EX1814956_SF2001234',
#  'EX1814967_SF2001234',
#  'EX1814972_SF2001234',
#  'EX1815020_SF2001234',
#  'EX1815070_SF2001234',
#  'EX1815231_SF2001234',
#  'EX1815289_SF2001234',
#  'EX1815303_SF2001234',
#  'EX1815458_SF2001234',
#  'EX1815468_SF2001234',
#  'EX1815481_SF2001234',
#  'EX1815526_SF2001234',
#  'EX1815533_SF2001234',
#  'EX1815574_SF2001234',
#  'EX1815576_SF2001234',
#  'EX1815589_SF2001234',
#  'EX1815592_SF2001234',
#  'EX1815601_SF2001234',
#  'EX1815610_SF2001234',
#  'EX1815652_SF2001234',
#  'EX1815656_SF2001234',
#  'EX1815669_SF2001234',
#  'EX1815698_SF2001234',
#  'EX1815704_SF2001234',
#  'EX1815720_SF2001234',
#  'EX1815815_SF2001234',
#  'EX1815821_SF2001234',
#  'EX1815868_SF2001234',
#  'EX1815869_SF2001234',
#  'EX1815886_SF2001234',
#  'EX1815890_SF2001234',
#  'EX1815915_SF2001234',
#  'EX1815935_SF2001234',
#  'EX1815936_SF2001234',
#  'EX1815937_SF2001234',
#  'EX1815942_SF2001234',
#  'EX1815946_SF2001234',
#  'EX1815950_SF2001234',
#  'EX1815971_SF2001234',
#  'EX1815980_SF2001234',
#  'EX1816017_SF2001234',
#  'EX1816039_SF2001234',
#  'EX1816113_SF2001234',
#  'EX1816116_SF2001234',
#  'EX1816118_SF2001234',
#  'EX1816119_SF2001234',
#  'EX1816141_SF2001234',
#  'EX1816150_SF2001234',
#  'EX1816156_SF2001234',
#  'EX1816158_SF2001234',
#  'EX1816159_SF2001234',
#  'EX1816170_SF2001234',
#  'EX1816179_SF2001234',
#  'EX1816181_SF2001234',
#  'EX1816211_SF2001234',
#  'EX1816211_SF2001234',
#  'EX1816211_SF2001234',
#  'EX1816212_SF2001234',
#  'EX1816215_SF2001234',
#  'EX1816215_SF2001234',
#  'snvcontrol01_SF2001234']

# %%
# Create Well-Sample dictionary {well:Sample} from seq.csv
well_sample = {}
well = [x for x in seq[0].unique() if len(x) == 3]
seqID = [str(x)[:9] for x in seq[1].unique()]
for w, s in zip(well, seqID):
    well_sample[w] = s

# %%
# new seq dictionary, nested lists with mutdetails and genomic nomenclature
seq_mut = {k:[[],[]] for k in seqID}
for sample in seqID:
    for variant in tngs_mut:
        if sample == variant[:9]:
            try:
                seq_mut[sample][0].append(variant[10:])
            except:
                seq_mut[sample][0] = [variant[10:]]
    for genomic in tngs_genomic:
        if sample == str(genomic)[:9]:
            try:
                seq_mut[sample][1].append(str(genomic)[10:])
            except:
                seq_mut[sample][1] = [str(genomic)[10:]]
seq_mut
# Out:
# {'EX1100630': [['nan exnan p. g.'], []],
#  'EX1702245': [['nan exnan p. g.'], []],
#  'EX1714297': [['nan exnan p. g.'], []],
#  'EX1806104': [['nan exnan p. g.'], []],
#  'EX1806937': [['nan exnan p. g.'], []],
#  'EX1809676': [['nan exnan p. g.'], []],
#  'EX1812034': [['nan exnan p. g.'], []],
#  'EX1812591': [['GLIS3 ex4 p.Gln528Ter/N c.1582C>T/N',
#    'GLIS3 ex4 p.His520Asn/N c.1558C>A/N'],
#   ['Chr9(GRCh37):g.4117896G>A', 'Chr9(GRCh37):g.4117920G>T']],
#  'EX1813292': [['nan exnan p. g.'], []],
#  'EX1813352': [['nan exnan p. g.'], []],
#  'EX1813353': [['nan exnan p. g.'], []],
#  'EX1813386': [['GATA6 ex2 p.Pro63Ser/N c.187C>T/N'],
#   ['Chr18(GRCh37):g.19751292C>T']],
#  'EX1813403': [['nan exnan p. g.'], []],
#  'EX1813529': [['nan exnan p. g.'], []],
#  'EX1813576': [['nan exnan p. g.'], []],
#  'EX1813608': [['CASR ex7 p.Cys787Arg/N c.2359T>C/N'],
#   ['Chr3(GRCh37):g.122003160T>C']],
#  'EX1813656': [['nan exnan p. g.'], []],
#  'EX1813905': [['HNF4A ex8 p.Arg311Cys/N c.931C>T/N'],
#   ['Chr20(GRCh37):g.43052762C>T']],
#  'EX1813935': [['HNF4A ex8 p.Leu319dup/N c.956_958dup/N'],
#   ['Chr20(GRCh37):g.43052787_43052789dup']],
#  'EX1813937': [['nan exnan p. g.'], []],
#  'EX1813996': [['nan exnan p. g.'], []],
#  'EX1814024': [['nan exnan p. g.'], []],
#  'EX1814026': [['nan exnan p. g.'], []],
#  'EX1814264': [['nan exnan p. g.'], []],
#  'EX1814312': [['nan exnan p. g.'], []],
#  'EX1814341': [['INSR ex12 p.Thr771Met/N c.2312C>T/N'],
#   ['Chr19(GRCh37):g.7143057G>A']],
#  'EX1814400': [['nan exnan p. g.'], []],
#  'EX1814483': [['nan exnan p. g.'], []],
#  'EX1814502': [['nan exnan p. g.'], []],
#  'EX1814537': [['nan exnan p. g.'], []],
#  'EX1814546': [['nan exnan p. g.'], []],
#  'EX1814680': [['GCK ex5 p.Arg191Trp/N c.571C>T/N'],
#   ['Chr7(GRCh37):g.44189576G>A']],
#  'EX1814711': [['nan exnan p. g.'], []],
#  'EX1814713': [['nan exnan p. g.'], []],
#  'EX1814825': [['nan exnan p. g.'], []],
#  'EX1814881': [['nan exnan p. g.'], []],
#  'EX1814956': [['nan exnan p. g.'], []],
#  'EX1814967': [['nan exnan p. g.'], []],
#  'EX1814972': [['nan exnan p. g.'], []],
#  'EX1815020': [['nan exnan p. g.'], []],
#  'EX1815070': [['nan exnan p. g.'], []],
#  'EX1815231': [['HNF1A ex4 p.Glu275del/N c.824_826del/N'],
#   ['Chr12(GRCh37):g.121432077_121432079del']],
#  'EX1815289': [['ABCC8 ex37 p.Gly1479Arg/N c.4435G>A/N'],
#   ['Chr11(GRCh37):g.17415926C>T']],
#  'EX1815303': [['nan exnan p. g.'], []],
#  'EX1815458': [['nan exnan p. g.'], []],
#  'EX1815468': [['CASR ex2 p.Arg25Ter/N c._000388.3C>T/N'],
#   ['Chr3(GRCh37):g.121973109C>T']],
#  'EX1815481': [['nan exnan p. g.'], []],
#  'EX1815526': [['nan exnan p. g.'], []],
#  'EX1815533': [['nan exnan p. g.'], []],
#  'EX1815574': [['nan exnan p. g.'], []],
#  'EX1815576': [['CASR ex7 p.Gln983ArgfsTer/N c.2946del/N'],
#   ['Chr3(GRCh37):g.122003747del']],
#  'EX1815589': [['nan exnan p. g.'], []],
#  'EX1815592': [['nan exnan p. g.'], []],
#  'EX1815601': [['nan exnan p. g.'], []],
#  'EX1815610': [['nan exnan p. g.'], []],
#  'EX1815652': [['nan exnan p. g.'], []],
#  'EX1815656': [['SDHC ex5 p./N g.161326349-161326708del/N'],
#   ['chr1:161326349-161326708']],
#  'EX1815669': [['nan exnan p. g.'], []],
#  'EX1815698': [['HNF1A ex2 p.Trp165Ter/N c.494G>A/N'],
#   ['Chr12(GRCh37):g.121426803G>A']],
#  'EX1815704': [['nan exnan p. g.'], []],
#  'EX1815720': [['nan exnan p. g.'], []],
#  'EX1815815': [['nan exnan p. g.'], []],
#  'EX1815821': [['MT-TL1 ex1 p./N c.L1:14A>G/N'], ['NC_012920.1:g.3243A>G']],
#  'EX1815868': [['nan exnan p. g.'], []],
#  'EX1815869': [['PHEX ex2 p. g.22056421-22056780del'],
#   ['chrX:22056421-22056780']],
#  'EX1815886': [['TG ex25 p.Val1664Met/N c.4990G>A/N'],
#   ['Chr8(GRCh37):g.133948058G>A']],
#  'EX1815890': [['HNF4A ex2 p.Arg67Gln/N c.200G>A/N'],
#   ['Chr20(GRCh37):g.43034848G>A']],
#  'EX1815915': [['ABCC8 ex13 p.Glu612Lys/N c.1834G>A/N'],
#   ['Chr11(GRCh37):g.17450201C>T']],
#  'EX1815935': [['nan exnan p. g.'], []],
#  'EX1815936': [['nan exnan p. g.'], []],
#  'EX1815937': [['nan exnan p. g.'], []],
#  'EX1815942': [['nan exnan p. g.'], []],
#  'EX1815946': [['nan exnan p. g.'], []],
#  'EX1815950': [['nan exnan p. g.'], []],
#  'EX1815971': [['nan exnan p. g.'], []],
#  'EX1815980': [['HNF1A ex4 p.Pro291Gln/N c.872C>A/N'],
#   ['Chr12(GRCh37):g.121432125C>A']],
#  'EX1816017': [['nan exnan p. g.'], []],
#  'EX1816039': [['nan exnan p. g.'], []],
#  'EX1816113': [['nan exnan p. g.'], []],
#  'EX1816116': [['nan exnan p. g.'], []],
#  'EX1816118': [['SDHA ex2 p.Asp49Gly/N c.146A>G/N'],
#   ['Chr5(GRCh37):g.223679A>G']],
#  'EX1816119': [['nan exnan p. g.'], []],
#  'EX1816141': [['CASR ex7 p.Pro748Arg/N c.2243C>G/N'],
#   ['Chr3(GRCh37):g.122003044C>G']],
#  'EX1816150': [['HNF1A ex7 p.Pro447Leu/N c.1340C>T/N'],
#   ['Chr12(GRCh37):g.121435307C>T']],
#  'EX1816156': [['nan exnan p. g.'], []],
#  'EX1816158': [['nan exnan p. g.'], []],
#  'EX1816159': [['nan exnan p. g.'], []],
#  'EX1816170': [['PHEX ex4 p. g.22094349-22094708del'],
#   ['chrX:22094349-22094708']],
#  'EX1816179': [['nan exnan p. g.'], []],
#  'EX1816181': [['nan exnan p. g.'], []],
#  'EX1816211': [['TBX6 ex6 p.Arg272Gln/N c.815G>A/N',
#    'TBX6 ex4 p.Gly162Ser/N c.484G>A/N',
#    'TBX6 ex4 p.Arg119His/N c.356G>A/N'],
#   ['Chr16(GRCh37):g.30099890C>T',
#    'Chr16(GRCh37):g.30100401C>T',
#    'Chr16(GRCh37):g.30100529C>T']],
#  'EX1816212': [['nan exnan p. g.'], []],
#  'EX1816215': [['SLC34A3 ex8 p.Thr267Pro/N c.799A>C/N',
#    'PHEX ex12 p.Trp456Cys c.1368G>T'],
#   ['Chr9(GRCh37):g.140128127A>C', 'ChrX(GRCh37):g.22151705G>T']],
#  'Sample Na': [[], []],
#  'cnvcontro': [[], []],
#  'snvcontro': [[], []]}

# %%
len(seqID)
# Out:
# 97
